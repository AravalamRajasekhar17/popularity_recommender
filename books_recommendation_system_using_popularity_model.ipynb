# %%
import turicreate

# %%
books_data=turicreate.SFrame('/content/sample_data/book selection-1.csv')
# Out:
# Finished parsing file /content/sample_data/book selection-1.csv
# Parsing completed. Parsed 100 lines in 0.053447 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,str,str,int]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /content/sample_data/book selection-1.csv
# Parsing completed. Parsed 1058 lines in 0.023492 secs.

# %%
books_data
# Out:
# Columns:
# 	S.NO	int
# 	Submitted Time	str
# 	1. Name	str
# 	2. select book	str
# 	3. Number of quantity	int
#
# Rows: 1058
#
# Data:
# +------+----------------+--------------+-------------------------------+-----------------------+
# | S.NO | Submitted Time |   1. Name    |         2. select book        | 3. Number of quantity |
# +------+----------------+--------------+-------------------------------+-----------------------+
# |  1   |   02-08-2022   |    Manasa    | Head-First Python,2nd edition |           2           |
# |  2   |   03-08-2022   |  Rajasekhar  | Python Crash course by Eri... |           1           |
# |  3   |   03-08-2022   |  Rajasekhar  | Head-First Python,2nd edition |           1           |
# |  4   |   03-08-2022   |    Manasa    | Data structure and algorit... |           1           |
# |  5   |   03-08-2022   | Hari Prakash | python programming:using p... |           1           |
# ...

# %%
train_data,test_data=books_data.random_split(.8,seed=0)

# %%
popularity_model=turicreate.popularity_recommender.create(train_data,user_id='1. Name',item_id='2. select book')
# Out:
# ...
#  To use one of these as a rating column, specify the column name to be used as target
#     and use a method that allows the use of a target.
# Preparing data set.
#     Data has 843 observations with 498 users and 27 items.
#     Data prepared in: 0.013292s
# 843 observations to process; with 27 unique items.

# %%
popularity_model.recommend(users=['B Pradeep'],k=5)
# Out:
# Columns:
# 	1. Name	str
# 	2. select book	str
# 	score	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-----------+--------------------------------+-------+------+
# |  1. Name  |         2. select book         | score | rank |
# +-----------+--------------------------------+-------+------+
# | B Pradeep |    Data science for dummies    |  67.0 |  1   |
# | B Pradeep |  Machine learning with python  |  59.0 |  2   |
# | B Pradeep |   Data science from scratch    |  50.0 |  3   |
# | B Pradeep | Machine learning for beginners |  47.0 |  4   |
# | B Pradeep | Practical statistics for d...  |  44.0 |  5   |
# +-----------+--------------------------------+-------+------+
# [5 rows x 4 columns]
